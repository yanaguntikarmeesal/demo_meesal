# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/demo_meesal/blob/main/if_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q 1)take two number from the user and print the greater one

# %%
#if condition
#take two number from the user and print the greater one

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

if a > b:
  print("The  greater value is a : ",a)
if b > a:
  print("The greater value is b : ",b)

# %% [markdown]
# Q 2) enter  the value from the user and check the number is true or false

# %%
 # Q 2) enter  the value from the user and check the number is true or false

a = int(input("Enter the value: "))

if a % 2 == 0:
    print("number entered by the user is even number")
if a % 2 != 0:
    print("number entered by the user is not even")

# %% [markdown]
# Q 3) umpire tossed a coin, if head = team a will bat first, if tail = b will bat first ?

# %%
# Q 3) umpire tossed a coin, if head = team a will bat first, if tail = b will bat first ?

a = input("tossed a coin  ")

if a == "head":
  print("team a will bat first ")
if a == "tail":
  print("team b will bat first ")

# %% [markdown]
# Q 4) enter a number from the user and check the number is divisible by 13 or not ?

# %%
# Q 4) enter a number from the user and check the number is divisible by 13 or not ?

a = int(input("Enter the number : "))

if a % 13 == 0:
  print("number is divisible by 13")
if a % 13 != 0:
  print("number is not divisible by 13")

# %% [markdown]
# Q 5) raju went for shopping if he purchase blue ball than he will play from the side of blue team, if raju will purchase green ball then he will play from the side of green team ?

# %%
# Q 5) raju went for shopping if he purchase blue ball than he will play from the side of blue team, if raju will purchase green ball then he will play from the side of green team ?

a = input("enter the color of ball : ")

if a == "blue":
  print("raju will play from the side of blue team")
if a == "green":
  print("raju will play from the side of green team")

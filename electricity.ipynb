# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/demo_meesal/blob/main/electricity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bill pay of electricity

# %%
def details_bill():
    print("the last date of the bill payment is on text week sunday")
    print("after deadline you need to pay rs 1000 as a fine")
    print("pay your bill soon")

for i in range(1):#number of person
    a = input("enter your name : ")
    print("my name is : ",a)
    b = int(input("enter the unit os electricity you have consumed : "))
    print("we consumed the electricity is : ",b)
    bill = b * 10
    print("total amount of bill have to pay is : ",bill)
    details_bill()

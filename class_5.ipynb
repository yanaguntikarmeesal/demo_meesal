# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/demo_meesal/blob/main/class_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20
c = a + b
print(c)

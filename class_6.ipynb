# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/demo_meesal/blob/main/class_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To check the Email id

# %%
email = input("please enter your mail address ")
print("the email is :",email)

valid_email = False

while not valid_email:
    if "@" in email and "." in email:
        print("email address validation passed ")
        valid_email = True
    else:
        print("invalid email address format please try again ")
        email = input("please enter your mail address ")

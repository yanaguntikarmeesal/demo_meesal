# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/demo_meesal/blob/main/if_else_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q 1) take a value from the user and if the value will be greater than 20 print magic ?

# %%
# Q 1) take a value from the user and if the value will be greater than 20 print magic ?

a = int(input("enter a number"))
if a > 20:
    print("magic")
else:
  print("not magic")

# %% [markdown]
# Q 2) enter the age of the user , if age greater  than 60 senior citizen,or not senior citizen

# %%
#Q 2) enter the age of the user , if age greater  than 60 senior citizen,or not senior citizen

a = int(input("please enter your age : "))
if a >= 60:
    print("senior citizen")
else:
    print("not senior citizen")

# %% [markdown]
# Q 3) ask the user to enter his age if the age will be more than 18 year than eleigible for voting

# %%
# Q 3) ask the user to enter his age if the age will be more than 18 year than eleigible for voting

a = int(input("please enter your age : "))
if a >= 18:
    print("eleigible for voting")
else:
    print("not eleigible for voting")
